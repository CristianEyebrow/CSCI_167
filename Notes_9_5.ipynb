# %% [markdown]
# <a href="https://colab.research.google.com/github/CristianEyebrow/CSCI_167/blob/main/Notes_9_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 9.5: Augmentation**
#
# This notebook investigates data augmentation for the MNIST-1D model.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-78n4ddyy
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-78n4ddyy
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=1c1d39a86a9b67a5233f4578393f4de0740327d07dfddbe3a4a99ede6efd6db5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_cn36jqs/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 200   # Hidden dimensions
D_o = 10    # Output dimensions

# Define a model with two hidden layers of size 200
# And ReLU activations between them
model = nn.Sequential(
nn.Linear(D_i, D_k),
nn.ReLU(),
nn.Linear(D_k, D_k),
nn.ReLU(),
nn.Linear(D_k, D_o))

def weights_init(layer_in):
  # Initialize the parameters with He initialization
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
errors_train = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  print(f'Epoch {epoch:5d}, train error {errors_train[epoch]:3.2f}, test error {errors_test[epoch]:3.2f}')
# Out:
# Epoch     0, train error 54.75, test error 62.60
# Epoch     1, train error 42.65, test error 52.20
# Epoch     2, train error 34.32, test error 47.70
# Epoch     3, train error 26.82, test error 44.70
# Epoch     4, train error 21.30, test error 43.10
# Epoch     5, train error 17.80, test error 40.20
# Epoch     6, train error 12.93, test error 39.60
# Epoch     7, train error 12.03, test error 40.40
# Epoch     8, train error 8.43, test error 39.20
# Epoch     9, train error 4.75, test error 37.40
# Epoch    10, train error 3.40, test error 39.40
# Epoch    11, train error 3.10, test error 36.40
# Epoch    12, train error 1.97, test error 35.20
# Epoch    13, train error 0.43, test error 36.10
# Epoch    14, train error 0.32, test error 37.10
# Epoch    15, train error 0.07, test error 36.10
# Epoch    16, train error 0.05, test error 35.20
# Epoch    17, train error 0.00, test error 35.70
# Epoch    18, train error 0.00, test error 34.40
# Epoch    19, train error 0.00, test error 35.20
# Epoch    20, train error 0.00, test error 35.40
# Epoch    21, train error 0.00, test error 35.20
# Epoch    22, train error 0.00, test error 35.40
# Epoch    23, train error 0.00, test error 34.50
# Epoch    24, train error 0.00, test error 35.10
# Epoch    25, train error 0.00, test error 34.80
# Epoch    26, train error 0.00, test error 35.30
# Epoch    27, train error 0.00, test error 35.20
# Epoch    28, train error 0.00, test error 34.80
# Epoch    29, train error 0.00, test error 35.00
# Epoch    30, train error 0.00, test error 34.80
# Epoch    31, train error 0.00, test error 34.90
# Epoch    32, train error 0.00, test error 34.80
# Epoch    33, train error 0.00, test error 35.00
# Epoch    34, train error 0.00, test error 35.10
# Epoch    35, train error 0.00, test error 34.90
# Epoch    36, train error 0.00, test error 34.80
# Epoch    37, train error 0.00, test error 35.00
# Epoch    38, train error 0.00, test error 34.70
# Epoch    39, train error 0.00, test error 34.70
# Epoch    40, train error 0.00, test error 34.90
# Epoch    41, train error 0.00, test error 34.90
# Epoch    42, train error 0.00, test error 35.00
# Epoch    43, train error 0.00, test error 34.30
# Epoch    44, train error 0.00, test error 34.70
# Epoch    45, train error 0.00, test error 34.40
# Epoch    46, train error 0.00, test error 34.80
# Epoch    47, train error 0.00, test error 34.70
# Epoch    48, train error 0.00, test error 34.60
# Epoch    49, train error 0.00, test error 34.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Train Error %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The best test performance is about 33%.  Let's see if we can improve on that by augmenting the data.

# %%
def augment(input_vector):
  # Create output vector
  data_out = np.zeros_like(input_vector)

  # TODO:  Shift the input data by a random offset
  # (rotating, so points that would go off the end, are added back to the beginning)
  # Replace this line:
  shift_amount = np.random.randint(0, len(input_vector))
  data_out = np.roll(input_vector, shift_amount)

  # TODO:    # Randomly scale the data by a factor drawn from a uniform distribution over [0.8,1.2]
  # Replace this line:
  data_out = np.array(data_out) * np.random.uniform(0.8, 1.2)

  return data_out

# %%
n_data_orig = data['x'].shape[0]
# We'll double the amount of data
n_data_augment = n_data_orig+4000
augmented_x = np.zeros((n_data_augment, D_i))
augmented_y = np.zeros(n_data_augment)
# First n_data_orig rows are original data
augmented_x[0:n_data_orig,:] = data['x']
augmented_y[0:n_data_orig] = data['y']

# Fill in rest of with augmented data
for c_augment in range(n_data_orig, n_data_augment):
  # Choose a data point randomly
  random_data_index = random.randint(0, n_data_orig-1)
  # Augment the point and store
  augmented_x[c_augment,:] = augment(data['x'][random_data_index,:])
  augmented_y[c_augment] = data['y'][random_data_index]

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 50 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(augmented_x.astype('float32'))
y_train = torch.tensor(augmented_y.transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
errors_train_aug = np.zeros((n_epoch))
errors_test_aug = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train_aug[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test_aug[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  print(f'Epoch {epoch:5d}, train error {errors_train_aug[epoch]:3.2f}, test error {errors_test_aug[epoch]:3.2f}')
# Out:
# Epoch     0, train error 53.26, test error 60.80
# Epoch     1, train error 40.56, test error 49.30
# Epoch     2, train error 34.29, test error 43.00
# Epoch     3, train error 29.01, test error 39.40
# Epoch     4, train error 26.75, test error 40.40
# Epoch     5, train error 22.01, test error 37.10
# Epoch     6, train error 18.60, test error 36.60
# Epoch     7, train error 15.99, test error 36.90
# Epoch     8, train error 14.55, test error 36.80
# Epoch     9, train error 13.60, test error 35.60
# Epoch    10, train error 10.57, test error 34.80
# Epoch    11, train error 7.76, test error 33.20
# Epoch    12, train error 7.11, test error 33.10
# Epoch    13, train error 5.41, test error 35.70
# Epoch    14, train error 4.97, test error 34.60
# Epoch    15, train error 1.80, test error 32.80
# Epoch    16, train error 1.30, test error 33.40
# Epoch    17, train error 0.68, test error 33.70
# Epoch    18, train error 0.29, test error 33.10
# Epoch    19, train error 0.00, test error 32.50
# Epoch    20, train error 0.00, test error 31.40
# Epoch    21, train error 0.00, test error 31.90
# Epoch    22, train error 0.00, test error 32.20
# Epoch    23, train error 0.00, test error 31.40
# Epoch    24, train error 0.00, test error 32.20
# Epoch    25, train error 0.00, test error 32.20
# Epoch    26, train error 0.00, test error 32.00
# Epoch    27, train error 0.00, test error 32.00
# Epoch    28, train error 0.00, test error 31.60
# Epoch    29, train error 0.00, test error 31.40
# Epoch    30, train error 0.00, test error 32.50
# Epoch    31, train error 0.00, test error 32.60
# Epoch    32, train error 0.00, test error 32.10
# Epoch    33, train error 0.00, test error 32.40
# Epoch    34, train error 0.00, test error 32.40
# Epoch    35, train error 0.00, test error 32.30
# Epoch    36, train error 0.00, test error 32.30
# Epoch    37, train error 0.00, test error 31.70
# Epoch    38, train error 0.00, test error 32.50
# Epoch    39, train error 0.00, test error 32.70
# Epoch    40, train error 0.00, test error 32.10
# Epoch    41, train error 0.00, test error 32.70
# Epoch    42, train error 0.00, test error 32.50
# Epoch    43, train error 0.00, test error 32.40
# Epoch    44, train error 0.00, test error 32.90
# Epoch    45, train error 0.00, test error 32.50
# Epoch    46, train error 0.00, test error 32.50
# Epoch    47, train error 0.00, test error 33.00
# Epoch    48, train error 0.00, test error 32.60
# Epoch    49, train error 0.00, test error 32.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.plot(errors_test_aug,'g-',label='test (augmented)')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train_aug[-1],errors_test_aug[-1]))
ax.legend()
plt.show()

# %% [markdown]
# Hopefully, you should see an improvement in performance when we augment the data.

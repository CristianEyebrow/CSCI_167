# %% [markdown]
# <a href="https://colab.research.google.com/github/CristianEyebrow/CSCI_167/blob/main/Notes_10_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-zcla1053
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-zcla1053
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=cebd3d1b890e46a18ce9ec424676d1dc5becc539fa6b5ffcb11df2a48581d46a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-126rfuhp/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.241474, train error 86.45,  val loss 2.233868, percent error 85.00
# Epoch     1, train loss 1.890030, train error 71.80,  val loss 1.890723, percent error 75.10
# Epoch     2, train loss 1.564928, train error 62.95,  val loss 1.576842, percent error 62.50
# Epoch     3, train loss 1.379031, train error 53.62,  val loss 1.379747, percent error 57.90
# Epoch     4, train loss 1.241402, train error 49.35,  val loss 1.247741, percent error 53.00
# Epoch     5, train loss 1.249029, train error 50.60,  val loss 1.268995, percent error 55.10
# Epoch     6, train loss 1.107849, train error 43.38,  val loss 1.107203, percent error 45.80
# Epoch     7, train loss 0.980373, train error 39.65,  val loss 1.008223, percent error 42.10
# Epoch     8, train loss 0.974696, train error 38.92,  val loss 0.999917, percent error 40.70
# Epoch     9, train loss 0.851286, train error 33.93,  val loss 0.908529, percent error 38.10
# Epoch    10, train loss 0.725617, train error 28.43,  val loss 0.787124, percent error 33.70
# Epoch    11, train loss 0.602364, train error 23.53,  val loss 0.667687, percent error 26.60
# Epoch    12, train loss 0.576587, train error 22.05,  val loss 0.632972, percent error 25.60
# Epoch    13, train loss 0.463036, train error 17.75,  val loss 0.525655, percent error 20.90
# Epoch    14, train loss 0.468687, train error 18.45,  val loss 0.567846, percent error 22.80
# Epoch    15, train loss 0.425593, train error 16.20,  val loss 0.521098, percent error 20.40
# Epoch    16, train loss 0.386619, train error 14.35,  val loss 0.474527, percent error 19.10
# Epoch    17, train loss 0.420474, train error 16.35,  val loss 0.547778, percent error 21.00
# Epoch    18, train loss 0.359465, train error 13.43,  val loss 0.484075, percent error 17.20
# Epoch    19, train loss 0.287672, train error 10.72,  val loss 0.393210, percent error 14.80
# Epoch    20, train loss 0.238978, train error 8.12,  val loss 0.364154, percent error 13.10
# Epoch    21, train loss 0.223508, train error 8.18,  val loss 0.360245, percent error 12.80
# Epoch    22, train loss 0.228334, train error 8.55,  val loss 0.370830, percent error 12.90
# Epoch    23, train loss 0.195533, train error 6.95,  val loss 0.330904, percent error 12.50
# Epoch    24, train loss 0.193846, train error 7.12,  val loss 0.343552, percent error 12.00
# Epoch    25, train loss 0.183830, train error 6.62,  val loss 0.322846, percent error 11.30
# Epoch    26, train loss 0.158713, train error 5.43,  val loss 0.319314, percent error 11.50
# Epoch    27, train loss 0.165847, train error 5.75,  val loss 0.319855, percent error 11.00
# Epoch    28, train loss 0.172747, train error 6.57,  val loss 0.343891, percent error 10.90
# Epoch    29, train loss 0.163368, train error 5.70,  val loss 0.345586, percent error 11.10
# Epoch    30, train loss 0.159639, train error 5.43,  val loss 0.327565, percent error 12.50
# Epoch    31, train loss 0.145676, train error 5.25,  val loss 0.327677, percent error 11.30
# Epoch    32, train loss 0.153568, train error 5.90,  val loss 0.334554, percent error 11.70
# Epoch    33, train loss 0.124427, train error 4.12,  val loss 0.321898, percent error 10.30
# Epoch    34, train loss 0.115052, train error 3.57,  val loss 0.316620, percent error 10.00
# Epoch    35, train loss 0.141453, train error 4.85,  val loss 0.366976, percent error 11.40
# Epoch    36, train loss 0.118444, train error 4.22,  val loss 0.336174, percent error 10.90
# Epoch    37, train loss 0.111139, train error 3.95,  val loss 0.316606, percent error 11.10
# Epoch    38, train loss 0.113692, train error 4.30,  val loss 0.321663, percent error 10.30
# Epoch    39, train loss 0.101130, train error 3.15,  val loss 0.345233, percent error 11.30
# Epoch    40, train loss 0.084696, train error 2.60,  val loss 0.320253, percent error 10.20
# Epoch    41, train loss 0.080478, train error 2.28,  val loss 0.331607, percent error 10.40
# Epoch    42, train loss 0.073902, train error 2.18,  val loss 0.317167, percent error 9.90
# Epoch    43, train loss 0.071766, train error 2.03,  val loss 0.312465, percent error 9.70
# Epoch    44, train loss 0.069568, train error 1.85,  val loss 0.320656, percent error 9.80
# Epoch    45, train loss 0.068326, train error 1.85,  val loss 0.321351, percent error 10.50
# Epoch    46, train loss 0.069461, train error 2.07,  val loss 0.332956, percent error 9.80
# Epoch    47, train loss 0.072609, train error 2.45,  val loss 0.319047, percent error 10.40
# Epoch    48, train loss 0.063661, train error 1.78,  val loss 0.318857, percent error 10.00
# Epoch    49, train loss 0.068673, train error 1.82,  val loss 0.352450, percent error 10.60
# Epoch    50, train loss 0.061660, train error 1.70,  val loss 0.328837, percent error 10.20
# Epoch    51, train loss 0.059578, train error 1.65,  val loss 0.332748, percent error 10.10
# Epoch    52, train loss 0.059800, train error 1.60,  val loss 0.341514, percent error 10.10
# Epoch    53, train loss 0.065977, train error 2.07,  val loss 0.369965, percent error 11.00
# Epoch    54, train loss 0.061203, train error 1.75,  val loss 0.322635, percent error 10.70
# Epoch    55, train loss 0.054373, train error 1.45,  val loss 0.328336, percent error 10.30
# Epoch    56, train loss 0.059655, train error 1.65,  val loss 0.358983, percent error 10.50
# Epoch    57, train loss 0.058957, train error 1.70,  val loss 0.335057, percent error 9.60
# Epoch    58, train loss 0.059979, train error 1.68,  val loss 0.329274, percent error 10.20
# Epoch    59, train loss 0.052283, train error 1.30,  val loss 0.340265, percent error 10.40
# Epoch    60, train loss 0.045971, train error 0.90,  val loss 0.338642, percent error 9.80
# Epoch    61, train loss 0.050990, train error 1.30,  val loss 0.327997, percent error 10.00
# Epoch    62, train loss 0.044386, train error 0.85,  val loss 0.338468, percent error 10.00
# Epoch    63, train loss 0.044083, train error 0.90,  val loss 0.343595, percent error 9.40
# Epoch    64, train loss 0.042981, train error 0.88,  val loss 0.346666, percent error 10.00
# Epoch    65, train loss 0.042213, train error 0.82,  val loss 0.338219, percent error 9.70
# Epoch    66, train loss 0.042130, train error 0.85,  val loss 0.352630, percent error 9.90
# Epoch    67, train loss 0.042301, train error 0.88,  val loss 0.350728, percent error 9.80
# Epoch    68, train loss 0.040465, train error 0.70,  val loss 0.344505, percent error 10.00
# Epoch    69, train loss 0.043832, train error 1.03,  val loss 0.345343, percent error 10.60
# Epoch    70, train loss 0.042528, train error 0.80,  val loss 0.347269, percent error 10.60
# Epoch    71, train loss 0.040008, train error 0.78,  val loss 0.346528, percent error 9.60
# Epoch    72, train loss 0.039641, train error 0.75,  val loss 0.355211, percent error 9.80
# Epoch    73, train loss 0.038030, train error 0.60,  val loss 0.348695, percent error 9.90
# Epoch    74, train loss 0.038827, train error 0.70,  val loss 0.364705, percent error 10.10
# Epoch    75, train loss 0.037686, train error 0.68,  val loss 0.346714, percent error 10.10
# Epoch    76, train loss 0.037493, train error 0.70,  val loss 0.358610, percent error 9.60
# Epoch    77, train loss 0.036586, train error 0.57,  val loss 0.365050, percent error 10.40
# Epoch    78, train loss 0.035769, train error 0.53,  val loss 0.352771, percent error 10.00
# Epoch    79, train loss 0.035284, train error 0.60,  val loss 0.355874, percent error 10.10
# Epoch    80, train loss 0.034481, train error 0.45,  val loss 0.361577, percent error 10.00
# Epoch    81, train loss 0.034145, train error 0.50,  val loss 0.357262, percent error 9.70
# Epoch    82, train loss 0.034997, train error 0.55,  val loss 0.363876, percent error 10.20
# Epoch    83, train loss 0.034094, train error 0.53,  val loss 0.355654, percent error 9.80
# Epoch    84, train loss 0.034178, train error 0.62,  val loss 0.363227, percent error 10.00
# Epoch    85, train loss 0.033866, train error 0.47,  val loss 0.355478, percent error 10.00
# Epoch    86, train loss 0.033307, train error 0.45,  val loss 0.359514, percent error 9.80
# Epoch    87, train loss 0.033179, train error 0.50,  val loss 0.365939, percent error 10.00
# Epoch    88, train loss 0.032735, train error 0.47,  val loss 0.364469, percent error 9.90
# Epoch    89, train loss 0.032681, train error 0.43,  val loss 0.363088, percent error 9.90
# Epoch    90, train loss 0.033171, train error 0.53,  val loss 0.360796, percent error 10.40
# Epoch    91, train loss 0.032183, train error 0.45,  val loss 0.362135, percent error 9.70
# Epoch    92, train loss 0.032539, train error 0.45,  val loss 0.363806, percent error 9.70
# Epoch    93, train loss 0.031894, train error 0.45,  val loss 0.369511, percent error 10.00
# Epoch    94, train loss 0.031550, train error 0.43,  val loss 0.365031, percent error 9.90
# Epoch    95, train loss 0.031444, train error 0.40,  val loss 0.367891, percent error 10.00
# Epoch    96, train loss 0.031337, train error 0.40,  val loss 0.368086, percent error 9.90
# Epoch    97, train loss 0.031337, train error 0.32,  val loss 0.367050, percent error 9.60
# Epoch    98, train loss 0.030846, train error 0.40,  val loss 0.367691, percent error 9.90
# Epoch    99, train loss 0.030643, train error 0.43,  val loss 0.367941, percent error 10.00

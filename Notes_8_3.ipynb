# %% [markdown]
# <a href="https://colab.research.google.com/github/CristianEyebrow/CSCI_167/blob/main/Notes_8_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-ze5pfqnd
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-ze5pfqnd
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=c376ca73516392227edfe0954fbfe40e9db8ed169ff4dbb7443649768b757c3a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rshiklo8/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.304492, train error 90.93,  test loss 2.307516, test error 91.10
# Epoch   100, train loss 1.897297, train error 72.15,  test loss 1.753114, test error 69.85
# Epoch   200, train loss 1.893254, train error 71.22,  test loss 1.736758, test error 68.95
# Epoch   300, train loss 1.889508, train error 71.53,  test loss 1.732817, test error 69.22
# Epoch   400, train loss 1.889420, train error 71.28,  test loss 1.743899, test error 68.65
# Epoch   500, train loss 1.885377, train error 70.82,  test loss 1.730926, test error 67.82
# Epoch   600, train loss 1.884641, train error 70.90,  test loss 1.727727, test error 68.70
# Epoch   700, train loss 1.895026, train error 70.32,  test loss 1.732513, test error 69.20
# Epoch   800, train loss 1.881730, train error 70.38,  test loss 1.741036, test error 68.45
# Epoch   900, train loss 1.882023, train error 70.53,  test loss 1.739775, test error 68.55
# Training model with   4 hidden variables
# Epoch     0, train loss 2.285985, train error 86.75,  test loss 2.284985, test error 87.38
# Epoch   100, train loss 1.774796, train error 66.05,  test loss 1.611372, test error 64.10
# Epoch   200, train loss 1.757157, train error 64.85,  test loss 1.607502, test error 62.90
# Epoch   300, train loss 1.749982, train error 64.57,  test loss 1.596112, test error 62.30
# Epoch   400, train loss 1.748628, train error 64.95,  test loss 1.604053, test error 62.38
# Epoch   500, train loss 1.751506, train error 65.80,  test loss 1.611372, test error 63.08
# Epoch   600, train loss 1.745637, train error 64.88,  test loss 1.600316, test error 62.62
# Epoch   700, train loss 1.746401, train error 65.78,  test loss 1.597241, test error 62.65
# Epoch   800, train loss 1.742770, train error 65.22,  test loss 1.597188, test error 62.15
# Epoch   900, train loss 1.744674, train error 64.55,  test loss 1.611836, test error 63.08
# Training model with   6 hidden variables
# Epoch     0, train loss 2.281669, train error 86.30,  test loss 2.284635, test error 86.32
# Epoch   100, train loss 1.689578, train error 59.83,  test loss 1.566014, test error 58.75
# Epoch   200, train loss 1.632866, train error 58.47,  test loss 1.502003, test error 57.15
# Epoch   300, train loss 1.571687, train error 55.58,  test loss 1.433950, test error 53.15
# Epoch   400, train loss 1.560728, train error 55.28,  test loss 1.429229, test error 52.72
# Epoch   500, train loss 1.564090, train error 55.30,  test loss 1.431744, test error 53.28
# Epoch   600, train loss 1.556487, train error 55.28,  test loss 1.426774, test error 53.33
# Epoch   700, train loss 1.555596, train error 55.12,  test loss 1.431244, test error 52.92
# Epoch   800, train loss 1.553699, train error 54.92,  test loss 1.433637, test error 53.22
# Epoch   900, train loss 1.564277, train error 54.78,  test loss 1.441007, test error 53.58
# Training model with   8 hidden variables
# Epoch     0, train loss 2.307665, train error 89.18,  test loss 2.310072, test error 89.68
# Epoch   100, train loss 1.618277, train error 57.20,  test loss 1.471872, test error 56.80
# Epoch   200, train loss 1.578104, train error 56.08,  test loss 1.457396, test error 55.67
# Epoch   300, train loss 1.554791, train error 55.28,  test loss 1.444606, test error 54.42
# Epoch   400, train loss 1.540658, train error 54.20,  test loss 1.443487, test error 54.10
# Epoch   500, train loss 1.532220, train error 53.90,  test loss 1.431272, test error 54.58
# Epoch   600, train loss 1.516575, train error 53.28,  test loss 1.419316, test error 53.70
# Epoch   700, train loss 1.514447, train error 53.08,  test loss 1.426325, test error 53.55
# Epoch   800, train loss 1.511268, train error 53.00,  test loss 1.423677, test error 53.42
# Epoch   900, train loss 1.508351, train error 52.50,  test loss 1.432211, test error 53.45
# Training model with  10 hidden variables
# Epoch     0, train loss 2.275598, train error 87.40,  test loss 2.272105, test error 85.38
# Epoch   100, train loss 1.569061, train error 56.22,  test loss 1.440372, test error 55.38
# Epoch   200, train loss 1.526953, train error 53.65,  test loss 1.441597, test error 55.53
# Epoch   300, train loss 1.503964, train error 53.10,  test loss 1.452446, test error 56.20
# Epoch   400, train loss 1.493886, train error 51.92,  test loss 1.463312, test error 56.30
# Epoch   500, train loss 1.491204, train error 52.12,  test loss 1.473978, test error 56.45
# Epoch   600, train loss 1.485405, train error 51.67,  test loss 1.475399, test error 55.90
# Epoch   700, train loss 1.484830, train error 51.60,  test loss 1.479027, test error 57.08
# Epoch   800, train loss 1.480662, train error 51.10,  test loss 1.477081, test error 56.45
# Epoch   900, train loss 1.481010, train error 51.55,  test loss 1.487724, test error 56.80
# Training model with  14 hidden variables
# Epoch     0, train loss 2.276977, train error 85.25,  test loss 2.295268, test error 85.10
# Epoch   100, train loss 1.480196, train error 50.45,  test loss 1.427302, test error 54.90
# Epoch   200, train loss 1.395326, train error 47.50,  test loss 1.394657, test error 53.40
# Epoch   300, train loss 1.336785, train error 45.42,  test loss 1.377670, test error 50.20
# Epoch   400, train loss 1.315330, train error 44.80,  test loss 1.402960, test error 50.42
# Epoch   500, train loss 1.306916, train error 44.83,  test loss 1.425487, test error 51.05
# Epoch   600, train loss 1.293698, train error 43.38,  test loss 1.431557, test error 51.50
# Epoch   700, train loss 1.285840, train error 43.58,  test loss 1.437401, test error 51.65
# Epoch   800, train loss 1.276812, train error 43.50,  test loss 1.458531, test error 51.78
# Epoch   900, train loss 1.262813, train error 43.45,  test loss 1.487042, test error 51.80
# Training model with  18 hidden variables
# Epoch     0, train loss 2.239535, train error 83.18,  test loss 2.242395, test error 83.45
# Epoch   100, train loss 1.352467, train error 43.47,  test loss 1.282387, test error 47.95
# Epoch   200, train loss 1.268132, train error 42.28,  test loss 1.308914, test error 47.85
# Epoch   300, train loss 1.207092, train error 40.62,  test loss 1.343099, test error 49.05
# Epoch   400, train loss 1.192194, train error 40.67,  test loss 1.403776, test error 50.30
# Epoch   500, train loss 1.190111, train error 40.60,  test loss 1.425552, test error 50.97
# Epoch   600, train loss 1.156100, train error 38.95,  test loss 1.431835, test error 50.00
# Epoch   700, train loss 1.149901, train error 38.40,  test loss 1.447851, test error 49.60
# Epoch   800, train loss 1.143653, train error 37.95,  test loss 1.479964, test error 50.35
# Epoch   900, train loss 1.133241, train error 38.17,  test loss 1.481574, test error 50.40
# Training model with  22 hidden variables
# Epoch     0, train loss 2.257594, train error 84.32,  test loss 2.225482, test error 83.05
# Epoch   100, train loss 1.254243, train error 41.38,  test loss 1.271132, test error 47.55
# Epoch   200, train loss 1.134335, train error 37.60,  test loss 1.331849, test error 48.75
# Epoch   300, train loss 1.069777, train error 35.65,  test loss 1.401571, test error 49.15
# Epoch   400, train loss 1.036261, train error 34.95,  test loss 1.478152, test error 50.15
# Epoch   500, train loss 1.021785, train error 33.85,  test loss 1.526354, test error 50.30
# Epoch   600, train loss 1.000324, train error 33.90,  test loss 1.576034, test error 51.60
# Epoch   700, train loss 0.990301, train error 34.18,  test loss 1.642341, test error 52.03
# Epoch   800, train loss 0.977642, train error 33.05,  test loss 1.687186, test error 51.95
# Epoch   900, train loss 0.959779, train error 33.47,  test loss 1.733935, test error 51.88
# Training model with  26 hidden variables
# Epoch     0, train loss 2.211343, train error 82.47,  test loss 2.174865, test error 81.45
# Epoch   100, train loss 1.193584, train error 39.00,  test loss 1.302801, test error 48.35
# Epoch   200, train loss 1.034958, train error 34.60,  test loss 1.381621, test error 47.78
# Epoch   300, train loss 0.961128, train error 32.28,  test loss 1.544713, test error 50.33
# Epoch   400, train loss 0.927940, train error 31.50,  test loss 1.648296, test error 50.47
# Epoch   500, train loss 0.896389, train error 30.28,  test loss 1.721531, test error 51.92
# Epoch   600, train loss 0.867391, train error 28.60,  test loss 1.830703, test error 52.58
# Epoch   700, train loss 0.857199, train error 28.85,  test loss 1.916298, test error 53.38
# Epoch   800, train loss 0.833809, train error 28.60,  test loss 1.978642, test error 53.22
# Epoch   900, train loss 0.810270, train error 27.40,  test loss 2.055448, test error 53.20
# Training model with  30 hidden variables
# Epoch     0, train loss 2.141017, train error 81.07,  test loss 2.120149, test error 80.38
# Epoch   100, train loss 1.081311, train error 34.72,  test loss 1.372558, test error 49.70
# Epoch   200, train loss 0.919099, train error 30.15,  test loss 1.566210, test error 52.62
# Epoch   300, train loss 0.846102, train error 27.78,  test loss 1.805418, test error 53.55
# Epoch   400, train loss 0.779211, train error 25.80,  test loss 1.989148, test error 55.25
# Epoch   500, train loss 0.747921, train error 25.12,  test loss 2.167999, test error 55.38
# Epoch   600, train loss 0.701059, train error 23.53,  test loss 2.307265, test error 56.25
# Epoch   700, train loss 0.687626, train error 23.72,  test loss 2.446809, test error 55.53
# Epoch   800, train loss 0.668066, train error 22.25,  test loss 2.568383, test error 55.78
# Epoch   900, train loss 0.678498, train error 23.32,  test loss 2.727181, test error 56.65
# Training model with  35 hidden variables
# Epoch     0, train loss 2.107343, train error 78.30,  test loss 2.065303, test error 77.32
# Epoch   100, train loss 0.993175, train error 32.70,  test loss 1.409007, test error 48.95
# Epoch   200, train loss 0.772955, train error 26.25,  test loss 1.758919, test error 51.53
# Epoch   300, train loss 0.644723, train error 20.88,  test loss 2.105850, test error 53.62
# Epoch   400, train loss 0.555457, train error 18.30,  test loss 2.529145, test error 55.03
# Epoch   500, train loss 0.508648, train error 17.18,  test loss 2.885850, test error 54.95
# Epoch   600, train loss 0.461306, train error 15.43,  test loss 3.232704, test error 56.67
# Epoch   700, train loss 0.469304, train error 16.65,  test loss 3.478873, test error 54.53
# Epoch   800, train loss 0.419751, train error 14.80,  test loss 3.864173, test error 56.58
# Epoch   900, train loss 0.389627, train error 13.85,  test loss 4.144441, test error 57.50
# Training model with  40 hidden variables
# Epoch     0, train loss 2.154445, train error 80.00,  test loss 2.110035, test error 78.35
# Epoch   100, train loss 0.902347, train error 29.35,  test loss 1.431182, test error 48.95
# Epoch   200, train loss 0.629523, train error 20.70,  test loss 1.921807, test error 51.90
# Epoch   300, train loss 0.477949, train error 15.62,  test loss 2.489116, test error 54.10
# Epoch   400, train loss 0.406299, train error 13.62,  test loss 3.169394, test error 54.58
# Epoch   500, train loss 0.329253, train error 10.45,  test loss 3.851020, test error 55.42
# Epoch   600, train loss 0.314715, train error 11.18,  test loss 4.674842, test error 56.33
# Epoch   700, train loss 0.265017, train error 9.50,  test loss 5.412216, test error 56.85
# Epoch   800, train loss 0.335583, train error 11.70,  test loss 6.179865, test error 57.50
# Epoch   900, train loss 0.369427, train error 11.95,  test loss 6.872377, test error 58.03
# Training model with  45 hidden variables
# Epoch     0, train loss 2.073399, train error 76.47,  test loss 2.043113, test error 77.20
# Epoch   100, train loss 0.842121, train error 27.50,  test loss 1.569291, test error 51.75
# Epoch   200, train loss 0.480720, train error 14.80,  test loss 2.343634, test error 54.08
# Epoch   300, train loss 0.360602, train error 11.18,  test loss 3.392578, test error 57.00
# Epoch   400, train loss 0.261374, train error 8.12,  test loss 4.475202, test error 57.78
# Epoch   500, train loss 0.197748, train error 6.35,  test loss 5.578998, test error 57.33
# Epoch   600, train loss 0.219781, train error 7.85,  test loss 6.740529, test error 57.55
# Epoch   700, train loss 0.148592, train error 5.28,  test loss 7.863951, test error 58.17
# Epoch   800, train loss 0.014421, train error 0.00,  test loss 8.838501, test error 57.83
# Epoch   900, train loss 0.008986, train error 0.00,  test loss 9.611853, test error 57.62
# Training model with  50 hidden variables
# Epoch     0, train loss 2.082131, train error 77.43,  test loss 2.041106, test error 77.32
# Epoch   100, train loss 0.734417, train error 23.30,  test loss 1.529714, test error 49.88
# Epoch   200, train loss 0.348010, train error 10.30,  test loss 2.515293, test error 52.78
# Epoch   300, train loss 0.154849, train error 3.80,  test loss 3.954659, test error 54.62
# Epoch   400, train loss 0.035676, train error 0.00,  test loss 5.522234, test error 55.05
# Epoch   500, train loss 0.014819, train error 0.00,  test loss 6.581701, test error 55.60
# Epoch   600, train loss 0.009007, train error 0.00,  test loss 7.237533, test error 55.47
# Epoch   700, train loss 0.006305, train error 0.00,  test loss 7.734356, test error 55.60
# Epoch   800, train loss 0.004860, train error 0.00,  test loss 8.119385, test error 56.03
# Epoch   900, train loss 0.003875, train error 0.00,  test loss 8.437533, test error 55.85
# Training model with  55 hidden variables
# Epoch     0, train loss 2.087900, train error 78.18,  test loss 2.051340, test error 77.50
# Epoch   100, train loss 0.659942, train error 20.78,  test loss 1.661955, test error 50.62
# Epoch   200, train loss 0.212434, train error 4.50,  test loss 2.989356, test error 53.42
# Epoch   300, train loss 0.043957, train error 0.03,  test loss 4.625144, test error 54.08
# Epoch   400, train loss 0.015141, train error 0.00,  test loss 5.617340, test error 53.97
# Epoch   500, train loss 0.008772, train error 0.00,  test loss 6.243763, test error 54.47
# Epoch   600, train loss 0.005982, train error 0.00,  test loss 6.675887, test error 54.53
# Epoch   700, train loss 0.004481, train error 0.00,  test loss 7.009294, test error 54.38
# Epoch   800, train loss 0.003542, train error 0.00,  test loss 7.289706, test error 54.17
# Epoch   900, train loss 0.002900, train error 0.00,  test loss 7.516686, test error 54.30
# Training model with  60 hidden variables
# Epoch     0, train loss 2.105544, train error 78.75,  test loss 2.068153, test error 78.72
# Epoch   100, train loss 0.551609, train error 17.35,  test loss 1.836174, test error 51.97
# Epoch   200, train loss 0.110013, train error 1.32,  test loss 3.486756, test error 53.58
# Epoch   300, train loss 0.019578, train error 0.00,  test loss 5.003784, test error 54.25
# Epoch   400, train loss 0.009361, train error 0.00,  test loss 5.751623, test error 54.40
# Epoch   500, train loss 0.005885, train error 0.00,  test loss 6.239149, test error 54.08
# Epoch   600, train loss 0.004179, train error 0.00,  test loss 6.596039, test error 54.30
# Epoch   700, train loss 0.003213, train error 0.00,  test loss 6.875457, test error 54.28
# Epoch   800, train loss 0.002578, train error 0.00,  test loss 7.114433, test error 54.40
# Epoch   900, train loss 0.002145, train error 0.00,  test loss 7.311088, test error 54.42
# Training model with  70 hidden variables
# Epoch     0, train loss 2.079040, train error 76.97,  test loss 2.051719, test error 76.43
# Epoch   100, train loss 0.375591, train error 10.12,  test loss 1.949342, test error 52.03
# Epoch   200, train loss 0.032721, train error 0.00,  test loss 3.716589, test error 53.85
# Epoch   300, train loss 0.010736, train error 0.00,  test loss 4.555670, test error 54.33
# Epoch   400, train loss 0.006026, train error 0.00,  test loss 5.019445, test error 54.55
# Epoch   500, train loss 0.004068, train error 0.00,  test loss 5.339932, test error 54.58
# Epoch   600, train loss 0.002991, train error 0.00,  test loss 5.590157, test error 54.65
# Epoch   700, train loss 0.002353, train error 0.00,  test loss 5.787383, test error 54.70
# Epoch   800, train loss 0.001922, train error 0.00,  test loss 5.952979, test error 54.83
# Epoch   900, train loss 0.001619, train error 0.00,  test loss 6.093736, test error 54.90
# Training model with  80 hidden variables
# Epoch     0, train loss 2.023992, train error 74.90,  test loss 1.955866, test error 74.47
# Epoch   100, train loss 0.257731, train error 6.12,  test loss 2.240614, test error 52.40
# Epoch   200, train loss 0.019213, train error 0.00,  test loss 3.545144, test error 53.20
# Epoch   300, train loss 0.007798, train error 0.00,  test loss 4.104240, test error 53.55
# Epoch   400, train loss 0.004638, train error 0.00,  test loss 4.447230, test error 53.90
# Epoch   500, train loss 0.003213, train error 0.00,  test loss 4.686941, test error 53.97
# Epoch   600, train loss 0.002423, train error 0.00,  test loss 4.877203, test error 53.92
# Epoch   700, train loss 0.001921, train error 0.00,  test loss 5.028887, test error 53.85
# Epoch   800, train loss 0.001583, train error 0.00,  test loss 5.159506, test error 53.92
# Epoch   900, train loss 0.001340, train error 0.00,  test loss 5.271307, test error 53.90
# Training model with  90 hidden variables
# Epoch     0, train loss 2.012329, train error 74.68,  test loss 1.949567, test error 75.43
# Epoch   100, train loss 0.144116, train error 1.05,  test loss 2.065121, test error 50.55
# Epoch   200, train loss 0.015251, train error 0.00,  test loss 3.078957, test error 51.62
# Epoch   300, train loss 0.006642, train error 0.00,  test loss 3.479722, test error 51.22
# Epoch   400, train loss 0.004070, train error 0.00,  test loss 3.739749, test error 51.33
# Epoch   500, train loss 0.002868, train error 0.00,  test loss 3.929074, test error 51.28
# Epoch   600, train loss 0.002184, train error 0.00,  test loss 4.075974, test error 51.35
# Epoch   700, train loss 0.001745, train error 0.00,  test loss 4.196241, test error 51.38
# Epoch   800, train loss 0.001446, train error 0.00,  test loss 4.299667, test error 51.22
# Epoch   900, train loss 0.001228, train error 0.00,  test loss 4.388516, test error 51.22
# Training model with 100 hidden variables
# Epoch     0, train loss 1.991114, train error 74.18,  test loss 1.929939, test error 74.70
# Epoch   100, train loss 0.089495, train error 0.10,  test loss 2.244820, test error 50.58
# Epoch   200, train loss 0.012475, train error 0.00,  test loss 3.080282, test error 50.70
# Epoch   300, train loss 0.005790, train error 0.00,  test loss 3.435697, test error 51.00
# Epoch   400, train loss 0.003612, train error 0.00,  test loss 3.661037, test error 50.95
# Epoch   500, train loss 0.002571, train error 0.00,  test loss 3.823516, test error 50.97
# Epoch   600, train loss 0.001970, train error 0.00,  test loss 3.950933, test error 50.80
# Epoch   700, train loss 0.001582, train error 0.00,  test loss 4.057761, test error 50.70
# Epoch   800, train loss 0.001314, train error 0.00,  test loss 4.147594, test error 50.67
# Epoch   900, train loss 0.001119, train error 0.00,  test loss 4.226386, test error 50.65
# Training model with 120 hidden variables
# Epoch     0, train loss 1.976530, train error 72.28,  test loss 1.913459, test error 72.68
# Epoch   100, train loss 0.054190, train error 0.00,  test loss 2.359290, test error 51.15
# Epoch   200, train loss 0.009665, train error 0.00,  test loss 3.038517, test error 50.97
# Epoch   300, train loss 0.004785, train error 0.00,  test loss 3.346246, test error 51.22
# Epoch   400, train loss 0.003048, train error 0.00,  test loss 3.544742, test error 51.15
# Epoch   500, train loss 0.002198, train error 0.00,  test loss 3.693048, test error 51.30
# Epoch   600, train loss 0.001698, train error 0.00,  test loss 3.808349, test error 51.42
# Epoch   700, train loss 0.001373, train error 0.00,  test loss 3.905047, test error 51.50
# Epoch   800, train loss 0.001146, train error 0.00,  test loss 3.987780, test error 51.45
# Epoch   900, train loss 0.000980, train error 0.00,  test loss 4.059803, test error 51.60
# Training model with 140 hidden variables
# Epoch     0, train loss 1.946354, train error 70.72,  test loss 1.876455, test error 71.43
# Epoch   100, train loss 0.038411, train error 0.00,  test loss 2.197110, test error 50.05
# Epoch   200, train loss 0.008241, train error 0.00,  test loss 2.723523, test error 50.03
# Epoch   300, train loss 0.004192, train error 0.00,  test loss 2.967860, test error 50.25
# Epoch   400, train loss 0.002717, train error 0.00,  test loss 3.130708, test error 50.22
# Epoch   500, train loss 0.001970, train error 0.00,  test loss 3.247067, test error 50.10
# Epoch   600, train loss 0.001530, train error 0.00,  test loss 3.340848, test error 50.10
# Epoch   700, train loss 0.001242, train error 0.00,  test loss 3.417015, test error 50.10
# Epoch   800, train loss 0.001039, train error 0.00,  test loss 3.482777, test error 50.28
# Epoch   900, train loss 0.000890, train error 0.00,  test loss 3.540673, test error 50.28
# Training model with 160 hidden variables
# Epoch     0, train loss 1.932546, train error 71.12,  test loss 1.856932, test error 71.68
# Epoch   100, train loss 0.028423, train error 0.00,  test loss 2.014250, test error 47.62
# Epoch   200, train loss 0.007134, train error 0.00,  test loss 2.391625, test error 47.50
# Epoch   300, train loss 0.003761, train error 0.00,  test loss 2.580851, test error 47.42
# Epoch   400, train loss 0.002472, train error 0.00,  test loss 2.707642, test error 47.45
# Epoch   500, train loss 0.001811, train error 0.00,  test loss 2.803208, test error 47.60
# Epoch   600, train loss 0.001414, train error 0.00,  test loss 2.877908, test error 47.50
# Epoch   700, train loss 0.001152, train error 0.00,  test loss 2.941022, test error 47.60
# Epoch   800, train loss 0.000966, train error 0.00,  test loss 2.995059, test error 47.62
# Epoch   900, train loss 0.000830, train error 0.00,  test loss 3.042689, test error 47.67
# Training model with 180 hidden variables
# Epoch     0, train loss 1.937648, train error 72.32,  test loss 1.876557, test error 74.10
# Epoch   100, train loss 0.023947, train error 0.00,  test loss 2.084447, test error 48.53
# Epoch   200, train loss 0.006575, train error 0.00,  test loss 2.436313, test error 48.38
# Epoch   300, train loss 0.003525, train error 0.00,  test loss 2.618574, test error 47.95
# Epoch   400, train loss 0.002334, train error 0.00,  test loss 2.737419, test error 47.97
# Epoch   500, train loss 0.001718, train error 0.00,  test loss 2.826959, test error 48.00
# Epoch   600, train loss 0.001346, train error 0.00,  test loss 2.899094, test error 48.00
# Epoch   700, train loss 0.001099, train error 0.00,  test loss 2.959273, test error 48.00
# Epoch   800, train loss 0.000924, train error 0.00,  test loss 3.010728, test error 47.90
# Epoch   900, train loss 0.000794, train error 0.00,  test loss 3.056004, test error 47.90
# Training model with 200 hidden variables
# Epoch     0, train loss 1.899698, train error 67.95,  test loss 1.843624, test error 71.35
# Epoch   100, train loss 0.020297, train error 0.00,  test loss 2.008657, test error 48.55
# Epoch   200, train loss 0.005918, train error 0.00,  test loss 2.310789, test error 48.38
# Epoch   300, train loss 0.003231, train error 0.00,  test loss 2.473083, test error 48.78
# Epoch   400, train loss 0.002164, train error 0.00,  test loss 2.579319, test error 48.62
# Epoch   500, train loss 0.001601, train error 0.00,  test loss 2.661177, test error 48.72
# Epoch   600, train loss 0.001258, train error 0.00,  test loss 2.725456, test error 48.67
# Epoch   700, train loss 0.001030, train error 0.00,  test loss 2.779572, test error 48.60
# Epoch   800, train loss 0.000868, train error 0.00,  test loss 2.827210, test error 48.60
# Epoch   900, train loss 0.000747, train error 0.00,  test loss 2.868012, test error 48.60
# Training model with 250 hidden variables
# Epoch     0, train loss 1.895436, train error 69.30,  test loss 1.805551, test error 70.50
# Epoch   100, train loss 0.016849, train error 0.00,  test loss 1.823893, test error 46.22
# Epoch   200, train loss 0.005327, train error 0.00,  test loss 2.062909, test error 45.83
# Epoch   300, train loss 0.002961, train error 0.00,  test loss 2.188828, test error 45.88
# Epoch   400, train loss 0.001998, train error 0.00,  test loss 2.275854, test error 45.97
# Epoch   500, train loss 0.001487, train error 0.00,  test loss 2.341259, test error 46.03
# Epoch   600, train loss 0.001174, train error 0.00,  test loss 2.394750, test error 46.12
# Epoch   700, train loss 0.000963, train error 0.00,  test loss 2.439147, test error 46.12
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.477818, test error 46.12
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.510925, test error 46.15
# Training model with 300 hidden variables
# Epoch     0, train loss 1.857633, train error 67.43,  test loss 1.788076, test error 69.72
# Epoch   100, train loss 0.014038, train error 0.00,  test loss 1.885646, test error 46.65
# Epoch   200, train loss 0.004748, train error 0.00,  test loss 2.106775, test error 46.50
# Epoch   300, train loss 0.002690, train error 0.00,  test loss 2.225141, test error 46.30
# Epoch   400, train loss 0.001835, train error 0.00,  test loss 2.307421, test error 46.30
# Epoch   500, train loss 0.001375, train error 0.00,  test loss 2.370476, test error 46.30
# Epoch   600, train loss 0.001090, train error 0.00,  test loss 2.421426, test error 46.22
# Epoch   700, train loss 0.000898, train error 0.00,  test loss 2.464164, test error 46.17
# Epoch   800, train loss 0.000760, train error 0.00,  test loss 2.500886, test error 46.15
# Epoch   900, train loss 0.000657, train error 0.00,  test loss 2.533280, test error 46.20
# Training model with 400 hidden variables
# Epoch     0, train loss 1.838175, train error 64.78,  test loss 1.777821, test error 68.40
# Epoch   100, train loss 0.011555, train error 0.00,  test loss 1.799326, test error 46.42
# Epoch   200, train loss 0.004151, train error 0.00,  test loss 1.976564, test error 46.40

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
